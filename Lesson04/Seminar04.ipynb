# %% [markdown]
# # Урок 4. Визуальный анализ данных

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***
# ## Задание 1.
#
# ### 1.1. Изучите количество памяти с помощью matplotlib

# %%
df = pd.read_csv('./laptops_10.csv')
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                        Cpu   Ram  \
# 0                     Intel Core i5 2.3GHz   8GB
# 1                     Intel Core i5 1.8GHz   8GB
# 2               Intel Core i5 7200U 2.5GHz   8GB
# 3                     Intel Core i7 2.7GHz  16GB
# 4                     Intel Core i5 3.1GHz   8GB
# ...                                    ...   ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB
# 1299            Intel Core i7 6500U 2.5GHz  16GB
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1301            Intel Core i7 6500U 2.5GHz   6GB
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# 1           Intel HD Graphics 6000       macOS    1.34       898.94
# 2            Intel HD Graphics 620       No OS    1.86       575.00
# 3               AMD Radeon Pro 455       macOS    1.83      2537.45
# 4     Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80       638.00
# 1299         Intel HD Graphics 520  Windows 10    1.30      1499.00
# 1300             Intel HD Graphics  Windows 10    1.50       229.00
# 1301            AMD Radeon R5 M330  Windows 10    2.19       764.00
# 1302             Intel HD Graphics  Windows 10    2.20       369.00
#
#      Cpu_Company  Memory_Amount   Memory_Type
# 0          Intel            128           SSD
# 1          Intel            128  FlashStorage
# 2          Intel            256           SSD
# 3          Intel            512           SSD
# 4          Intel            256           SSD
# ...          ...            ...           ...
# 1298       Intel            128           SSD
# 1299       Intel            512           SSD
# 1300       Intel             64  FlashStorage
# 1301       Intel           1024           HDD
# 1302       Intel            500           HDD
#
# [1303 rows x 13 columns]

# %%
df['Memory_Amount'].value_counts()
# Out:
# 256     508
# 1024    250
# 128     177
# 512     140
# 500     132
# 32       45
# 64       17
# 2048     16
# 16       10
# 180       5
# 240       1
# 8         1
# 508       1
# Name: Memory_Amount, dtype: int64

# %%
plt.figure(figsize=(5,5))

plt.hist(df['Memory_Amount'], bins=10)

plt.title('Анализ ноутбуков в зависимости от объема памяти')
plt.xlabel('Объем памяти, GB')
plt.ylabel('Количество ноутбуков');

# %% [markdown]
# ### 1.2. Изучите стоимость ноутбуков с помощью matplotlib

# %%
df['Price_euros'].value_counts()
# Out:
# 1499.0    14
# 1099.0    14
# 1799.0    14
# 899.0     11
# 1199.0    11
#           ..
# 2090.0     1
# 304.0      1
# 759.0      1
# 1858.0     1
# 2699.0     1
# Name: Price_euros, Length: 791, dtype: int64

# %%
plt.figure(figsize=(10,5))

sns.histplot(df['Price_euros'], bins=100)

plt.title('Анализ ноутбуков в зависимости от стоимости')
plt.xlabel('Стоимость в евро')
plt.ylabel('Количество ноутбуков');

# %% [markdown]
# ### 1.3. Изучите вес ноутбуков с помощью matplotlib

# %%
df['Weight'].value_counts()
# Out:
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 3.25      1
# 2.34      1
# Name: Weight, Length: 171, dtype: int64

# %%
plt.figure(figsize=(10,5))

sns.histplot(df['Weight'], bins=50)

plt.title('Анализ ноутбуков в зависимости от веса')
plt.xlabel('Вес (кг)')
plt.ylabel('Количество ноутбуков');

# %% [markdown]
# ## Задание 2.
#
# ### 2.1. Изучите распределение типов носителя

# %%
data = df['Memory_Type'].value_counts()
data
# Out:
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: Memory_Type, dtype: int64

# %%
plt.figure(figsize=(8,8))

plt.pie(data.values, autopct='%1.1f%%', labels=data.index)
plt.legend(data.index);

# %% [markdown]
# ### 2.2. Изучите распределение компаний производителей

# %%
data = df['Company'].value_counts()
data
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
plt.figure(figsize=(10,6))

sns.barplot(x=data.index, y=data.values, palette='mako')

plt.title('Анализ ноутбуков в зависимости от компаний производителей')
plt.xticks(rotation=45);

# %% [markdown]
# ### 2.3. Изучите распределение операционной системы

# %%
data = df['OpSys'].value_counts()
data
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
plt.figure(figsize=(8, 8))

expl = [0.2, 0.03, 0.04, 0.05, 0.07, 0.06, 0.05, 0.04, 0.5]
plt.pie(data.values, autopct='%1.1f%%', labels=data.index, explode=expl)

plt.title('Доля типов носителей')
plt.legend(data.index, loc='best');

# %%
plt.figure(figsize=(10,6))

sns.barplot(x=data.index, y=data.values)

plt.title('распределение операционной системы')
plt.xticks(rotation=45);

# %% [markdown]
# ### 2.4. Изучите распределение компаний производителей CPU

# %%
data = df['Cpu_Company'].value_counts()
data
# Out:
# Intel      1240
# AMD          62
# Samsung       1
# Name: Cpu_Company, dtype: int64

# %%
plt.figure(figsize=(5, 5))

explode = [0.5, 0.3, 0.7]
plt.pie(data.values, autopct='%1.1f%%', labels=data.index, explode=explode, colors = ["0.9", "g", "#FF00BB",])

plt.title('Распределение компаний производителей CPU')
plt.legend(data.index, loc='best');

# %%
plt.figure(figsize=(5, 5))

explode = [0.5, 0.3, 0.7]
colors = sns.color_palette('bright')
plt.pie(data.values, autopct='%1.1f%%', labels=data.index, explode=explode, colors = colors)

plt.title('Распределение компаний производителей CPU')
plt.legend(data.index, loc='best');

# %% [markdown]
# ## Задание 3.
#
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму. Процессоры от Samsung не изучайте.
#
# ### 3.1. Постройте график в абсолютных величинах

# %%
data = pd.crosstab(df['Company'],df['Cpu_Company'])
data = data.drop('Samsung', axis=1).reset_index()
data
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
plt.figure(figsize=(10,5))

n_ticks = np.arange(data.shape[0])
offset = 0.2
w = 0.4

plt.bar(n_ticks - offset, data['Intel'], width=w)
plt.bar(n_ticks + offset, data['AMD'], width=w)

plt.title('Взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров')
plt.xlabel('Производители ноутбуков')
plt.ylabel('Кол-во')
plt.legend(['Intel','AMD'])
plt.xticks(n_ticks, data['Company'], rotation = 30);

# %%
df_company_process = pd.crosstab(df['Company'], df['Cpu_Company'])
df_company_process.drop('Samsung', axis=1, inplace = True)

plt.bar(df_company_process.index,df_company_process['AMD'], color='lightblue')
plt.bar(df_company_process.index,df_company_process['Intel'], bottom = df_company_process['AMD'])

plt.xticks(rotation = 45);

# %%
data = pd.crosstab(df['Company'],df['Cpu_Company'], normalize='index')
data = data.drop('Samsung', axis=1).reset_index()
data
# Out:
# Cpu_Company    Company       AMD     Intel
# 0                 Acer  0.097087  0.902913
# 1                Apple  0.000000  1.000000
# 2                 Asus  0.069620  0.930380
# 3                Chuwi  0.000000  1.000000
# 4                 Dell  0.000000  1.000000
# 5              Fujitsu  0.000000  1.000000
# 6               Google  0.000000  1.000000
# 7                   HP  0.091241  0.908759
# 8               Huawei  0.000000  1.000000
# 9                   LG  0.000000  1.000000
# 10              Lenovo  0.053872  0.946128
# 11                 MSI  0.000000  1.000000
# 12            Mediacom  0.000000  1.000000
# 13           Microsoft  0.000000  1.000000
# 14               Razer  0.000000  1.000000
# 15             Samsung  0.000000  0.888889
# 16             Toshiba  0.000000  1.000000
# 17                Vero  0.000000  1.000000
# 18              Xiaomi  0.000000  1.000000

# %%
plt.figure(figsize=(15, 6))

plt.bar(data['Company'], data['Intel'])
plt.bar(data['Company'], data['AMD'], bottom=data['Intel'])

plt.title('Производители процессоров')
plt.xlabel('призводители ноутбуков')
plt.ylabel('Доля процессоров')
plt.legend(['Intel','AMD'])
plt.xticks(rotation = 30);

# %% [markdown]
# ## Задание 4.
#
# ### 4.1. Изучите взаимосвязь стоимости ноутбука и компании производителя процессора

# %%
plt.figure(figsize=(16, 8))

sns.boxplot(y = df['Cpu_Company'], x = df['Price_euros']);

# %% [markdown]
# ### 4.2. Изучите взаимосвязь стоимости ноутбука и типа носителя памяти

# %%
plt.figure(figsize=(15,8))

sns.violinplot(y=df["Memory_Type"], x=df["Price_euros"]);

# %%
plt.figure(figsize=(15,8))

sns.boxplot(y=df["Memory_Type"], x=df["Price_euros"]);

# %% [markdown]
# ### 4.3. Изучите взаимосвязь стоимости ноутбука и кол-ва оперативной памяти

# %%
plt.figure(figsize=(15,8))

sns.boxplot(y=df["Ram"], x=df["Price_euros"]);

# %% [markdown]
# ### 4.4. Изучите взаимосвязь стоимости ноутбука и компании производителя

# %%
plt.figure(figsize=(15,8))

sns.boxplot(y=df["Company"].sort_values(), x=df["Price_euros"]);

# %%
data = df['Company'].value_counts()

plt.figure(figsize=(15,8))
sns.barplot(data.index, data.values);

# %%
df[df['Company'] == 'HP'].sort_values('Price_euros', ascending=False).head(10)
# Out:
#      Company          Product            TypeName  Inches  \
# 749       HP         Zbook 17         Workstation    17.3
# 1136      HP         ZBook 17         Workstation    17.3
# 911       HP  Elitebook Folio           Ultrabook    12.5
# 1103      HP         ZBook 17         Workstation    17.3
# 857       HP   EliteBook x360  2 in 1 Convertible    13.3
# 316       HP     Spectre x360  2 in 1 Convertible    13.3
# 736       HP         ZBook 15         Workstation    15.6
# 1146      HP    EliteBook 820           Ultrabook    12.5
# 848       HP   EliteBook x360  2 in 1 Convertible    13.3
# 950       HP     ZBook Studio         Workstation    15.6
#
#                                 Cpu   Ram                     Gpu       OpSys  \
# 749   Intel Xeon E3-1535M v5 2.9GHz  16GB    Nvidia Quadro M2000M   Windows 7
# 1136    Intel Core i7 6700HQ 2.6GHz   8GB    Nvidia Quadro M3000M   Windows 7
# 911        Intel Core M 6Y75 1.2GHz   8GB   Intel HD Graphics 515  Windows 10
# 1103    Intel Core i7 6700HQ 2.6GHz   8GB      AMD FirePro W6150M   Windows 7
# 857      Intel Core i7 7600U 2.8GHz   8GB   Intel HD Graphics 620  Windows 10
# 316      Intel Core i7 8550U 1.8GHz  16GB  Intel UHD Graphics 620  Windows 10
# 736     Intel Core i7 7700HQ 2.8GHz  16GB     Nvidia Quadro M2200  Windows 10
# 1146    Intel Core i7 6500U 2.50GHz   8GB   Intel HD Graphics 520   Windows 7
# 848      Intel Core i5 7200U 2.5GHz   8GB   Intel HD Graphics 620  Windows 10
# 950     Intel Core i7 6820HQ 2.7GHz   8GB    Nvidia Quadro M1000M  Windows 10
#
#       Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type
# 749     3.00      4389.00       Intel            256         SSD
# 1136    3.00      3949.40       Intel            256         SSD
# 911     1.09      3100.00       Intel            240         SSD
# 1103    3.00      2899.00       Intel           1024         HDD
# 857     1.28      2559.00       Intel            256         SSD
# 316     1.29      2449.00       Intel           1024         SSD
# 736     2.60      2419.00       Intel            256         SSD
# 1146    1.26      2296.95       Intel            256         SSD
# 848     1.28      2277.00       Intel            256         SSD
# 950     2.00      2249.00       Intel              8         SSD

# %% [markdown]
# ## Задание 5.
#
# Постройте матрицу корреляций для таблицы

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                  Inches    Weight  Price_euros  Memory_Amount
# Inches         1.000000  0.827631     0.068197       0.269718
# Weight         0.827631  1.000000     0.210370       0.180557
# Price_euros    0.068197  0.210370     1.000000      -0.125363
# Memory_Amount  0.269718  0.180557    -0.125363       1.000000

# %%
corr_matrix = np.round(corr_matrix, 2)
corr_matrix
# Out:
#                Inches  Weight  Price_euros  Memory_Amount
# Inches           1.00    0.83         0.07           0.27
# Weight           0.83    1.00         0.21           0.18
# Price_euros      0.07    0.21         1.00          -0.13
# Memory_Amount    0.27    0.18        -0.13           1.00

# %%
corr_matrix[np.abs(corr_matrix)<=0.2] = 0
corr_matrix
# Out:
#                Inches  Weight  Price_euros  Memory_Amount
# Inches           1.00    0.83         0.00           0.27
# Weight           0.83    1.00         0.21           0.00
# Price_euros      0.00    0.21         1.00           0.00
# Memory_Amount    0.27    0.00         0.00           1.00

# %%
sns.heatmap(corr_matrix, annot=True);

# %%
upp_mat = np.triu(df.corr())
sns.heatmap(df.corr(), annot=True, cmap = 'viridis', mask = upp_mat);

# %%
pd.plotting.scatter_matrix(df);

# %%
sns.pairplot(df, height=2, kind="scatter", diag_kind="kde");
